# %%
print("Hello world")
# Out:
# Hello world

# %%
from services import useGroq, useGemini

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
groq = useGroq(api_key=os.getenv("GROQ"), temperature=0.1, max_tokens=200)

# %%
groq.give_response("Hello")
# Out:
# AIMessage(content='Hello. How can I help you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 36, 'total_tokens': 46, 'completion_time': 0.035728981, 'completion_tokens_details': None, 'prompt_time': 0.008638448, 'prompt_tokens_details': None, 'queue_time': 0.159802922, 'total_time': 0.044367429}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cbee8-a109-7550-9c28-0f3b8542d3f4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 36, 'output_tokens': 10, 'total_tokens': 46})

# %%
gemini = useGemini(api_key=os.getenv("GEMINI"), temperature=0.1, max_tokens=200)

# %%
gemini.give_response("Hello")
# Out:
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised NotFound: 404 models/gemini-3.0-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 4.0 seconds as it raised NotFound: 404 models/gemini-3.0-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 8.0 seconds as it raised NotFound: 404 models/gemini-3.0-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# ...
